# %%
import os
import cv2
import matplotlib.pyplot as plt

# %%
directory = 'image_dataset'
train_labels = []

with open('labels.txt', 'w') as f:

    for filename in os.listdir(directory):

        if (filename == '.DS_Store') :
            continue

        pathFile = os.path.join(directory, filename)

        # checking if it is a file
        if os.path.isfile(pathFile):

            print("PathFile corrente: ", pathFile)
            
            img = cv2.imread(pathFile)

            # plt.figure(figsize = [1, 1])
            plt.axis('off')
            plt.imshow(img)
            plt.show()

            
            word = input('Nome immagine: ')

            if (word == '0') :
                continue
            elif (word == 'end') :
                break

            tupla = (pathFile, None, word)

            print("tupla insert --> ", tupla)
            print()
            print()

            train_labels.append(tupla)


            stringToInsert = f'(\'{pathFile}\', None, \'{word}\'), '

            f.write(stringToInsert)
# Out:
# PathFile corrente:  image_dataset/img_842.png
# tupla insert -->  ('image_dataset/img_842.png', None, 'data')
#
#
# PathFile corrente:  image_dataset/img_1108.png
# tupla insert -->  ('image_dataset/img_1108.png', None, 'regionali')
#
#
# PathFile corrente:  image_dataset/img_856.png
# tupla insert -->  ('image_dataset/img_856.png', None, 'nascita')
#
#
# PathFile corrente:  image_dataset/img_659.png
