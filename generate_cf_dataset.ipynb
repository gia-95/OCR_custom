# %%
import keras_ocr
import matplotlib.pyplot as plt
import random
import cv2

# %%
fonts = ['fonts/40474_VerdanaBold.ttf', 'fonts/TitilliumWeb-Bold.ttf', 'fonts/TitilliumWeb-Regular.ttf', 'fonts/TitilliumWeb-SemiBold.ttf']
backgrounds =[
'backgrounds/solid-color-image (1).jpeg',
'backgrounds/solid-color-image (2).jpeg',
'backgrounds/solid-color-image (3).jpeg',
'backgrounds/solid-color-image (4).jpeg',
'backgrounds/solid-color-image (5).jpeg',
'backgrounds/solid-color-image (6).jpeg',
'backgrounds/solid-color-image (7).jpeg',
'backgrounds/solid-color-image (8).jpeg',
'backgrounds/solid-color-image (9).jpeg',
'backgrounds/solid-color-image (10).jpeg',
'backgrounds/solid-color-image (11).jpeg',
'backgrounds/solid-color-image (12).jpeg',
'backgrounds/solid-color-image (13).jpeg',
'backgrounds/solid-color-image (14).jpeg',
'backgrounds/solid-color-image (15).jpeg',
'backgrounds/solid-color-image (16).jpeg',
'backgrounds/solid-color-image (17).jpeg',
'backgrounds/solid-color-image (18).jpeg',
'backgrounds/solid-color-image.jpeg' 
]

print("fonts:",fonts[:2])
print("backgrounds:",backgrounds[:2])
# Out:
# fonts: ['fonts/40474_VerdanaBold.ttf', 'fonts/TitilliumWeb-Bold.ttf']
# backgrounds: ['backgrounds/solid-color-image (1).jpeg', 'backgrounds/solid-color-image (2).jpeg']

# %%
alphabet = '0123456789ABCDEFGHILMNOPQRSTUVZ'

image, line = keras_ocr.data_generation.draw_text_image(
    'MRNGLC89G67H567R', 
    fontsize=40, 
    height=43, 
    width=510, 
    fonts={
        alphabet: 'fonts/40474_VerdanaBold.ttf'
    },
    thetaX=0,
    thetaY=0,
    thetaZ=0, 
    )


text = keras_ocr.data_generation.convert_lines_to_paragraph(line)
print(text)
plt.imshow(image)
# Out:
# MRNGLC89G67H567R
# [255 255 255   0]

# %%
letters_alph = 'ABCDEFGHILMNOPQRSTUVZ'
numbers_aplh = '0123456789'

# print(print(letters_alph[random.randint(0, len(letters_alph)-1)]))


# es. 'GHLCVN 65 H 05 H 501 N'
cf_random_array = []

# 6 lettere
for n in range(6) :
    lettera_random = letters_alph[random.randint(0, len(letters_alph)-1)]
    cf_random_array.append(lettera_random)

# 2 numeri 
for n in range(2) :
    numero_rand = numbers_aplh[random.randint(0, len(numbers_aplh)-1)]
    cf_random_array.append(numero_rand)

# 1 lettera
for n in range(1) :
    lettera_random = letters_alph[random.randint(0, len(letters_alph)-1)]
    cf_random_array.append(lettera_random)

# Prime 2 numeri
for n in range(2) :
    numero_rand = numbers_aplh[random.randint(0, len(numbers_aplh)-1)]
    cf_random_array.append(numero_rand)

# 1 lettera
for n in range(1) :
    lettera_random = letters_alph[random.randint(0, len(letters_alph)-1)]
    cf_random_array.append(lettera_random)

# 3 numeri
for n in range(3) :
    numero_rand = numbers_aplh[random.randint(0, len(numbers_aplh)-1)]
    cf_random_array.append(numero_rand)

# 1 lettera
for n in range(1) :
    lettera_random = letters_alph[random.randint(0, len(letters_alph)-1)]
    cf_random_array.append(lettera_random)


cf_random = '' 
for ele in cf_random_array: 
    cf_random += ele

cf_random
# Out:
# 'GRMMFC05V78M768N'

# %%
alphabet = '0123456789ABCDEFGHILMNOPQRSTUVZ'

image, line = keras_ocr.data_generation.draw_text_image(
    cf_random, 
    fontsize=40, 
    height=63, 
    width=510, 
    fonts={
        alphabet: fonts[random.randint(0, len(fonts)-1)]
    },
    thetaX=0,
    thetaY=0,
    thetaZ=0, 
    )


text = keras_ocr.data_generation.convert_lines_to_paragraph(line)
print(text)
plt.imshow(image)
# Out:
# GRMMFC05V78M768N
